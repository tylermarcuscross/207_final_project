# %% [markdown]
# ### Importing Data

# %%
# !mkdir -p data/
# !cd data/
# !kaggle datasets download -d sujaykapadnis/emotion-recognition-dataset
# !unzip emotion-recognition-dataset.zip
# !rm emotion-recognition-dataset.zip
# !mv dataset data/
# !mv data.csv data/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/Sad/0a12a7e998fa7abde73e79ce2a74477bdc6f5dd010da05231f4c3330.jpg
#   inflating: dataset/Sad/0a1370fc7e34586d5f134694c9d1e79ed4cce9e59684077ae5061db8.png
#   inflating: dataset/Sad/0a14abb2a25753914205e88e870054918de36219552002f3144b8455.jpg
#   inflating: dataset/Sad/0a15eede4e05e13f70f6540c4167282f9a488cc318005c8693c49433.jpg
#   inflating: dataset/Sad/0a163aa46984ad37b58aa6b8175dca9b1007a3066099d18f4dda6f78.jpg
#   inflating: dataset/Sad/0a1833eb2427bd8c1ddd3b9c020c6233a3671763e21b1e08b5afa41f.jpg
#   inflating: dataset/Sad/0a19842e87935fbd2c45a7042e4bb8d1d3816476e8a6b7e8f41205d8.jpg
#   inflating: dataset/Sad/0a1d613237e9af295213c61e1c2b9d7fd211fad638c522afb9548901.jpg
#   inflating: dataset/Sad/0a1d86074a08f9bf55858cf90eaaee6f1e0362d97f08cbaa161e30e0.jpg
#   inflating: dataset/Sad/0a22b8d3b2fbcbebb6a4be7dad0a37b92983e8afe42b4d48cded4e45.jpg
#   inflating: dataset/Sad/0a285a2a07f0f8daaa0a821e30ad2e558ddc18f2589aa82582e92134.jpg
#   inflating: dataset/Sad/0a2a5151ea63e949c5dedf73cb494921effdc6deaf4cbc15b2d3a50d.jpg
#   inflating: dataset/Sad/0a30dfaabbed918c2b16b4c318de11fbcf154b0c59c6b1b1beec510c.png
#   inflating: dataset/Sad/0a33f5768ad9bf3e709f0a11656004b580c189f6e1f084ab34431bbf.png
#   inflating: dataset/Sad/0a3564da208755c76609281ee94753e8720ad86d1fb30f0b4b9ffd9e.jpg
#   inflating: dataset/Sad/0a3883e7a98dd2b6853c4fef8fae6f6c29568860027f203244e675c3.jpg
#   inflating: dataset/Sad/0a3b3058528fc68de17b75d06d05490be8e3b5cfb9917320f4031d2b.jpg
#   inflating: dataset/Sad/0a3be310a2c3ca022adb3a680ea4bd37c4ea4fefe92379b460634cd7.jpg
#   inflating: dataset/Sad/0a3e5abdb17d7ecaaef15fe435590a732833f3e5f0e6c5c53b8c1a6a.jpg
#   inflating: dataset/Sad/0a3f3c3d39ce9bf0b580887512c4986e1147e7f6f914c73ea9c6646a.JPG
#   inflating: dataset/Sad/0a42594842040ca15e5c678ab80e9606d5b55c38578971185dba06c2.JPG
#   inflating: dataset/Sad/0a42938039cbcaf53f22d0ec957a41d727218c3bdf6e94b9a91174d3.jpg
#   inflating: dataset/Sad/0a4312609258d048d9d09cfbaf1e2d4c6e1a795d227adc9455b911f0.jpg
#   inflating: dataset/Sad/0a467513804bc101cef9bed3966c2075931fb382ee0883cd85914965.jpg
#   inflating: dataset/Sad/0a4b03d1d54d73d267accf7a8fa2bca05ee9e7be429f5115d53bb125.jpg
#   inflating: dataset/Sad/0a4dcc17d4973007571c40c35f3b3082fc7ffc08919765ae43e45e6d.jpg
#   inflating: dataset/Sad/0a515831300aeb68d3b85fa03aaced7bf8b8f8cf2ecd2b111dad0f81.jpg
#   inflating: dataset/Sad/0a52c45183eb330cccae51573bb8050834dcb8ec62614d756c1c9d0f.jpg
#   inflating: dataset/Sad/0a5ecd8db6535c1853a816caa67336d330251b6b0cac69db92b9f0b7.jpg
#   inflating: dataset/Sad/0a5ff5db91098b3c01d39ed4524d3ea8679b226ddd10970c53c45f27.jpg
#   inflating: dataset/Sad/0a6067b1d03d32e1aa2495d0224299c55497d1e1fd540e2a61efd144.jpg
#   inflating: dataset/Sad/0a63daa74864165da656418e1307ee2423e0bccdf54f1cccba8d4f8e.jpg
#   inflating: dataset/Sad/0a6862217f7b2f0777ddb7376cec045f9717ccc001d2dcd5e2faba68.JPG
#   inflating: dataset/Sad/0a687a1797282f4d013d5b1942e1af525542a86c05407123c42080ab.jpg
#   inflating: dataset/Sad/0a69437891b2ae387c5068663f7d64d18a989111bda9d7aebc013b67.jpg
#   inflating: dataset/Sad/0a69a7896903ae4b023e0e53eeebefd5e08751d7dd6f758ec7c2be77.jpg
#   inflating: dataset/Sad/0a6c8b334e3f59d5d0078a7cbb83677e0b80aa618ca012071433b12d.jpg
#   inflating: dataset/Sad/0a6ff78a068767aea74d14a6a8fddc98cb9213e4c821c098626e54ff.jpg
#   inflating: dataset/Sad/0a7246e84247d4bf30d83c4e192acf3ec9d7a541056a262da1b06437.jpg
#   inflating: dataset/Sad/0a766b5d1f81e58cc2187b50028ed4e47e087c122cc73c31ced1e566.jpg
#   inflating: dataset/Sad/0a82a1107f6228f528d599a7141a5777d9bcb9ec1b397963ec262cb3.jpg
#   inflating: dataset/Sad/0a847093466c1e19fd0d79feef6e69dbcc2e7770feca349fe9f0268f.jpg
#   inflating: dataset/Sad/0a88b4afa7da5c8b565f170d95c2bb23e7d0a58fb8c58b6feb5b5c9d.jpg
#   inflating: dataset/Sad/0a89da8f0c60f03adc144760418d6c35ac925329339d054ae787d825.JPG
#   inflating: dataset/Sad/0a8f7614f154c336f414fa9c7319de92b689ad7e75125fd97ee460c2.jpg
#   inflating: dataset/Sad/0a8fe74458f04fd6eb981d81201d1c6d5e670ab9b4c20faa2bb96da5.jpg
#   inflating: dataset/Sad/0a9074c7edfd9112dc3728fe8864a4ebedfc12a728816e8629b55603.jpg
#   inflating: dataset/Sad/0a933c8c18d0ae5c60d7631d5b683825eaeff4b73095d881ddebb228.jpg
#   inflating: dataset/Sad/0a951f0add3c604b39a31925db19e1adfa9e13d05c55c2601d02be0b.jpg
#   inflating: dataset/Sad/0a99bf2b4084ca6a585d3c652f423fd8c5f451122b529ddd443b74c9.jpg
#   inflating: dataset/Sad/0a99c4d5722e89e814711baee88b38a9a6f60a1bd155879b162b7bfb.jpg
#   inflating: dataset/Sad/0a99d7ba999ec9098105d9025b589af2fb948916db675b90d8acbfc1.jpg
#   inflating: dataset/Sad/0a9de6bebd1de8a1e232594f9c2d9210ad239adf8c4db90d33a47ef4.jpg
#   inflating: dataset/Sad/0a9ec2c74836090d57d2d49fb8abde00e82de11d6e81127e3f7d8f55.jpg
#   inflating: dataset/Sad/0a9f7f99c24f844d7793e2acf0a40a93992a64411144a1452d035284.jpg
#   inflating: dataset/Sad/0aa23504dc30efb6e392c5fee838a1b5c8281fd2062a4a9902a9b392.jpg
#   inflating: dataset/Sad/0aa2699b0a3ae98aa612b9cf69e2e6915955f6453d3b32a4a0c239bb.jpg
#   inflating: dataset/Sad/0aa28ddfdcc5ef8b36d73955bf0fb74de656d2086b1561753539d4ab.jpg
#   inflating: dataset/Sad/0aa6d50b0fc978b5679b6c1df9ab788a2586e1cc0da603d83090d7c9.jpg
#   inflating: dataset/Sad/0aa98a58e0d2b91a025794c1f741c15a1e6dcc6dcdff1bdec28b6130.png
#   inflating: dataset/Sad/0ab8fbf3ac854c16a5e9560bcbe2d4a9839afb47a388ef896a6d5c47.jpg
#   inflating: dataset/Sad/0abc40670b7a57aa672a4b350ca98d8bcce6f80341ddfc3b799f8dcd.jpg
#   inflating: dataset/Sad/0abdc0e91c11281dd6820da7c8d11363c570c1b680640cc36d86b708.jpg
#   inflating: dataset/Sad/0abde9c1a5521d9aba3f3f103ec8564a87ee9753fd9a1ca8848d98b0.jpg
#   inflating: dataset/Sad/0abe075ddfe22a235febd08ac46a0f2850d496cfe658667fd9d98c88.jpeg
#   inflating: dataset/Sad/0abe4552facf8407e15e97608fed97c0a2c551c944a4d3e53c16a7b7.jpg
#   inflating: dataset/Sad/0ac252e39243611229294d449a3139af0d9b086ffb7005578de9ea03.jpg
#   inflating: dataset/Sad/0ace007d71d002bbc7b20ef3a52cec63d0941452ab458cc17d9259ef.jpg
#   inflating: dataset/Sad/0ad0277a4b453ee098b18822797a9d9f99e10e258a11a2eba26deac2.jpg
#   inflating: dataset/Sad/0ad3b6157dde82d8fa216bf345a5937b7fabfe785823c3cc37df9852.jpg
#   inflating: dataset/Sad/0ad66d2718e39670f0f44e3d53adae8b674c44a9588dec9a58eab27e.jpg
#   inflating: dataset/Sad/0ae4b33250f5939b0902a887da332988bf2c3a3f0e0c5a9346a07c6b.jpg
#   inflating: dataset/Sad/0ae61c2ed0f4834d47f6d1a9b3f2bb5c72690a5cb5b3248d00b20e1d.jpg
#   inflating: dataset/Sad/0ae8c54a2ba663736be51d1dbcf5cfa6438e1c657e8a23ef2992a139.jpg
#   inflating: dataset/Sad/0ae8dcbb0c00023613d311d1b6b6173ac68dd49b4afc8d5684fc5bdd.jpeg
#   inflating: dataset/Sad/0ae8dd7cf552cd6cb9222346ff6a9f5882dc66c0cb78789355220e8a.jpg
#   inflating: dataset/Sad/0aef12773fa409d0dab03ed74d73f8bccc9e4cb486983cc942d54dad.jpg
#   inflating: dataset/Sad/0af12cf2c251a8b1b9a3fbb605dc49c635afecc2acf63c7242993fa8.jpg
#   inflating: dataset/Sad/0af449115bbd5b59c5399905f7492faddf39fa037260d0c4940f37d7.jpg
#   inflating: dataset/Sad/0afc640cf968122937089238def0ab554daba2ae88a4936358623952.jpg
#   inflating: dataset/Sad/0afd0bcf8458ddc13aaea6abe4a87d6df5c072f822ba5bb277b04588.jpg
#   inflating: dataset/Sad/0b014741d5323024caaf68f9cae11d98ac183e8e4fd962313e4e22f0.jpg
#   inflating: dataset/Sad/0b01b6280de28ed955821472e6fe92edac973d22c90ae70c8f0446cc.JPG
#   inflating: dataset/Sad/0b047189f44dc8ad14dfb605715d67b828fa220b927c8e2896512caf.jpg
#   inflating: dataset/Sad/0b078180a40cc202077ff75611d7f502abc23422829f71ee2b805b55.jpg
#   inflating: dataset/Sad/0b085edc714e7760674314de0acdcbe043b635f2050edc369fd80d33.jpg
#   inflating: dataset/Sad/0b097948af2480357f744b487991e4b81f974bddfd5174510d7b24e4.JPG
#   inflating: dataset/Sad/0b0aaaa6cb12832a5956eb0be1dc55d48dabfaff0fb50b749c8b1d66.jpg
#   inflating: dataset/Sad/0b0f1090a68719623dabb88f6e461902b4309fdca641ea9369afbfb8.jpg
#   inflating: dataset/Sad/0b1040152218828705966fe7b6ae4d84ef194c3fec5a8853b64aa14f.bmp
#   inflating: dataset/Sad/0b129ba0da23c187b15645c6cbb6a67a607b953a5d12a8b764139611.jpg
#   inflating: dataset/Sad/0b136497e50a7ccb63deae5dc188bc3075fe6f1b2fef998960d84e72.jpg
#   inflating: dataset/Sad/0b138f3fc1c7928f030e886d2e5e44f6e565373985737e9499acf930.png
#   inflating: dataset/Sad/0b14533b2eb664084d3c944ce110863e53425a059827e44db95b2cce.jpg
#   inflating: dataset/Sad/0b14979100aa8129b54ec080ec6e4851dcb371e79268f5b921389b89.jpg
#   inflating: dataset/Sad/0b15a463f407dddfe3f0d8c26a0e67528ceaf8832b706ee0731c105e.jpg
#   inflating: dataset/Sad/0b17c90e703ce268813ec4db3cf5138b1fbce49b89592581eaea3c15.jpg
#   inflating: dataset/Sad/0b1939f24d58163242649337fbcc734ed73c3db2b683c3eb281fafd8.jpg
#   inflating: dataset/Sad/0b1b9559d91a797d2ae77721841a71fe7304647493d8ad7d4e5a5d14.jpg
#   inflating: dataset/Sad/0b22528f77f93b2a0c30f811d24845edf54e5931f427754e8dbcd0b4.jpg
#   inflating: dataset/Sad/0b241f3476923b6e95700d753f7dd8e5a9f36ec9d786846e076c5f92.jpg
#   inflating: dataset/Sad/0b260143868adf73d82e6d87bd1cd57c0f31c303bd6cdf07b5ae0b96.jpeg
#   inflating: dataset/Sad/0b28c36cf9ae14f548910c34d939d5965de7dfc4a27d14e8a48718bc.png
#   inflating: dataset/Sad/0b2ca21bd66e35e88675bf81cabd33af8aeb15d78ada534179699748.jpg
#   inflating: dataset/Sad/0b2e2610dcd1a1470c57e5111a98aa24dc9749c36065b5f21d6b69e3.jpg
#   inflating: dataset/Sad/0b3070f19899ecbae4e9b393c0ded72b97003a0c223d0dda3a7f1252.jpeg
#   inflating: dataset/Sad/0b336a03b9cf5d7886ab962ee5fd1841422292ba14a3f348f8292502.jpeg
#   inflating: dataset/Sad/0b33a4dcf06b8a2480d761fe124f2d2b931ad9625b173c053c1a27bb.jpg
#   inflating: dataset/Sad/0b35ba780731abec90fa5c1574fcc6c9f5f7b7bab69815ef1eb279d5.jpeg
#   inflating: dataset/Sad/0b36358c29e8f17d6770e795c923059f020c06ed9f3d573bd9e609a9.JPG
#   inflating: dataset/Sad/0b36464f11a989ad31e14b884d3cec1014cf71787d82ed7e1d7c83cb.jpg
#   inflating: dataset/Sad/0b3b013fb9e0b0a3f7b73f924543fca57e32c386d5bbbf57813fb5ef.jpg
#   inflating: dataset/Sad/0b3ba0a1717ce095413f4b4e4e98474c85803510640f42a0fc2fa13c.jpg
#   inflating: dataset/Sad/0b44643e5b353feb632c30dfad23a5dc2810f7307aab6d564234b134.png
#   inflating: dataset/Sad/0b4471dd6d99c7bcdb47e20cabafa6547c8fe853d01a362c8ae393f3.jpg
#   inflating: dataset/Sad/0b456c10fc06f0c8e4a3d2661d91fe809af0a331d72e9e713ba65552.JPG
#   inflating: dataset/Sad/0b4633bf66ad2818ce9b18cb29c6bbb4453f28d6e0297953dadc533f.jpg
#   inflating: dataset/Sad/0b4df4eb02eefe0b9407f0127a4da9994092ea42f1880aa156f63dfa.jpg
#   inflating: dataset/Sad/0b54e66c35f31e6a23780fb7bcbd64999eafe793f6d354bc13ceb9c3.jpg
#   inflating: dataset/Sad/0b5501d315ac1839dd338602adababb738b1b907a7343d52f7368790.jpg
#   inflating: dataset/Sad/0b5bb90e4bedab3bd8cb941f17ce625661abde287dac7d39e26805a3.jpg
#   inflating: dataset/Sad/0b5c1457f360ca4c3313f40b9ae2fe76dd9816ab2e4139358b5ae4fd.png
#   inflating: dataset/Sad/0b615ee9a7f19b8e8a30beedc4e7116ba6037bfb22bbfd64c8681bc7.jpg
#   inflating: dataset/Sad/0b61fa89937fe435a6d016a0ed2bbb7cbe5f85296641f1aa19067da7.jpg
#   inflating: dataset/Sad/0b621103bb3f4122d1509210e4eda71b98ee0589366efa93ab537d72.jpg
#   inflating: dataset/Sad/0b64362395f241a2be88e7ffb04b324f486d6ca82a1e819abb2181d2.jpg
#   inflating: dataset/Sad/0b65c70b6a79d5800af561c8b9ab421a13c2bd44cd1c138054c85b15.jpg
#   inflating: dataset/Sad/0b674684568b11be5ccda2be5c67f08614ab7a94127aafb44db69fe6.jpg
#   inflating: dataset/Sad/0b7183bc84271d2b876fbafa487719b78d75f41d05daca6eace3506c.jpg
#   inflating: dataset/Sad/0b71ab1bcb18501f267af7ba10d9e02e4c25ad4c4751406a7a5cdd40.png
#   inflating: dataset/Sad/0b726b6866c0d00641cf2a1e0eec34ef20db9de987cf00297883710d.jpg
#   inflating: dataset/Sad/0b7698f339603617a3d48fa18dab45d77679cf7f4be51bde9ee9ddc6.jpg
#   inflating: dataset/Sad/0b7b477ab292611fccd25befac6aaf0cd875ab76b1f5af2a242675f5.jpeg
#   inflating: dataset/Sad/0b7c2e47b174ddeff408f41e0c50dc5eace06d4724ff104f339b6739.jpg
#   inflating: dataset/Sad/0b7c78c6936b811aca5fd786d4417aa10c37ff4dd8697f1b011b9ef1.jpg
#   inflating: dataset/Sad/0b7ccf82a9318a675c41d7a5f5b8743ca4aac8b1828720fcad3ae884.jpg
#   inflating: dataset/Sad/0b7cdf2d1e24cfd973f28a5707098462fbd833a6168ad3313e1f9c06.jpg
#   inflating: dataset/Sad/0b7d4d412c0675bbb6ad7f65211bc464d2cf301eb0d66bb7b56fb726.png
#   inflating: dataset/Sad/0b801a90099e841bc1007f71f51321a89aaa863a36d9655e45b1a0d3.jpg
#   inflating: dataset/Sad/0b8bf54a108abbecc2eb4506d3e6b87ebdcecc0d3c51eaf4ce71040e.jpg
#   inflating: dataset/Sad/0b90b1e8efb1f93611ff12847dc8c244712bef9c1b7026fb0c773be3.jpg
#   inflating: dataset/Sad/0b91b55eb6aa1db0de25c90e01066e002cf367886a5598449d04d491.png
#   inflating: dataset/Sad/0b9908fee9daf73d8d1860bd8fd099a9c4ea99e08dedd363c761ff69.jpg
#   inflating: dataset/Sad/0ba107eb31f5a854dc1d32cb4effc319da6360d4de6ac0639921f1df.png
#   inflating: dataset/Sad/0ba655f89bac6be86e9dea4f06065acc94918c11656b765e50f07430.png
#   inflating: dataset/Sad/0ba71a6c9ae26009591ae81cd9b782ae34a3b671bfb4ec3bf284cf45.jpg
#   inflating: dataset/Sad/0ba98b6f79fd9ef654abdde92d9464071c1e501a10c6d07aec39e388.jpg
#   inflating: dataset/Sad/0baadbb5cc8b548cee01e47d834fa64ad301a17b9d36e5e217ff7ed1.jpg
#   inflating: dataset/Sad/0bace155606150a5a04fff169dad47ca47aa6669b5b10db2eb55b001.jpg
#   inflating: dataset/Sad/0bae1875a3da7c7f693933d81df32ca566674ac5e3de23fb7924da18.jpg
#   inflating: dataset/Sad/0bb0359ca31f569e9f40b1e4b5000162d5e2d480d8caac0b644612e5.jpg
#   inflating: dataset/Sad/0bb5e62a24f9e0874ffafde3eddfb518a5f7b7003758331cfcac88a0.JPG
#   inflating: dataset/Sad/0bb6c47ff03feb7f44e659e8f863938a41a3c7caada395da30884118.jpg
#   inflating: dataset/Sad/0bb786958031887d6d36a1dbd4380d94dd68a0064b1f060a6e0de682.jpg
#   inflating: dataset/Sad/0bb84ef39021c40b158599b0d6a52a6bd623bf9091f0875aba3b3a8d.jpg
#   inflating: dataset/Sad/0bbd74657766d5c1c2f451e40260fb7765f8908f4f8fcba57c21b8be.jpg
#   inflating: dataset/Sad/0bbf7ab28e40de659573ce0d043125c53e89e2c9394acf21e60bc5a9.jpg
#   inflating: dataset/Sad/0bc1e82b9b301b57cf30ee357c802e886e80bc4be6c325a3004ca8de.jpg
#   inflating: dataset/Sad/0bc425cdbfdcb72f0b5a85f0a135b917b497c089c5aa8abf448f26db.jpg
#   inflating: dataset/Sad/0bc455438668ae80ed4058d70eea4207be8f99f00e7d088b87e722a1.jpg
#   inflating: dataset/Sad/0bc593ff189f884ab6a259d1abfc6b51f49c2bc5e6be3e5ac93dff3d.jpeg
#   inflating: dataset/Sad/0bcdfa3e424b8e0e1f3758a141c96d73bfc703ac222c0387edb2d588.jpg
#   inflating: dataset/Sad/0bcee286016b7f0dcf97c15a5edef00194083f4d39a9485f2d88d11c.jpg
#   inflating: dataset/Sad/0bd15d989c5782b026fd7e183347ed63ffb24908c411465cf5885279.jpg
#   inflating: dataset/Sad/0bd4208a8c5700c9b53fc6d5eba6e92fda147ef194da19314e987fb3.jpg
#   inflating: dataset/Sad/0bd92e480d63cc698384528c59e450326899a48ca92cbe60d27d5ec9.jpg
#   inflating: dataset/Sad/0bdb2da1ce8f8c728d032880c7b55956126cfdd1f6d2dee75192a820.jpg
#   inflating: dataset/Sad/0bdbf24193e02ead498c64c103b707de7231f235e3de7ffaef4602b7.jpg
#   inflating: dataset/Sad/0bdcadf0646c920991834c2a530e6908d2d841d378a715240b84dab6.jpg
#   inflating: dataset/Sad/0bdda1979130dadf5751272840369257df71e0f91b2092286746ed35.jpg
#   inflating: dataset/Sad/0be0e11575bc16baed99859fff2105021c15b3a313523cb2b455e2d9.jpg
#   inflating: dataset/Sad/0be6344364b8afb453b2ec08bb89982d28b732d1f9cc371f0e16349e.png
#   inflating: dataset/Sad/0bea734fa5b225ae39b92f39fb742e73bfee359d644093263d7dbb28.JPG
#   inflating: dataset/Sad/0bee07cd92c63a466cad3710e6533d55ba8a452cf1217c5a782e7748.jpg
#   inflating: dataset/Sad/0bee8962cc7a49a7b13ca1907cd9ed8009bccbf39b24f846d179dcb4.jpg
#   inflating: dataset/Sad/0bf1b7e09cd5d02e0652f262423d757df695294f7b3a6be8eae44bc2.jpg
#   inflating: dataset/Sad/0bf5df53a229365dfe5d273b81ba7e090334068b0188d03bfff0110c.jpg
#   inflating: dataset/Sad/0bf9aec7675ecad7a4025f1916e2b3bb382f338cb87cf5531012ef8b.jpg
#   inflating: dataset/Sad/0bfc36bd40c82cee61d71b6534c68f8d96fb0770ff8ad543b1da8afe.jpg
#   inflating: dataset/Sad/0c01957cad9216acd9aee55b26432f620e3550df6e1e662a0ffd8c14.jpg
#   inflating: dataset/Sad/0c01da664520e18548f0bc6bc2467c27a876a1febfb3b5f7188dbc09.jpg
#   inflating: dataset/Sad/0c028913d1abc7bc2cfeed33758d42bee73626acdaacd779debbf533.jpg
#   inflating: dataset/Sad/0c04414658c277507d53767511f829889df5b037f7370ca5066f3eeb.jpeg
#   inflating: dataset/Sad/0c04931ae5ad52f63ad83ae858f404482baa9e07c8be3e79c634eb27.jpg
#   inflating: dataset/Sad/0c0597d6675a556a908ce5725fef80dd63cbc52371c3d8b4a606acab.jpg
#   inflating: dataset/Sad/0c0a0d4692e2afecd1c75b0519c2590a8953336cad1b6a118de06649.jpg
#   inflating: dataset/Sad/0c0a6d8a8b5efe6e878cbc795080f79de118fe74a391047440b2cb7d.jpg
#   inflating: dataset/Sad/0c0d0d4a585cf18b08a7f097dc78458e78151f7f2e28b653856c2510.png
#   inflating: dataset/Sad/0c0dc4a38e1561e7c24ec1601a639427c6f237083090c2fb0f8e9c7d.jpg
#   inflating: dataset/Sad/0c0e0aa3c3423be21450a7b5cf598c3463899db327a81e29e1ec2749.jpg
#   inflating: dataset/Sad/0c11eb5648c072f576feed7911fc1ff134675551491f699f5b369f03.jpg
#   inflating: dataset/Sad/0c131d635789a237a9011e562ee1106534654b5ba4cdadbb075034b0.jpg
#   inflating: dataset/Sad/0c1bf225b6ceb739bbab505e2693473f9c244e37886fae6529d998fd.jpg
#   inflating: dataset/Sad/0c1e182fa3404bba68c114f4869e0cd01ccba426614b94d19da7a541.jpg
#   inflating: dataset/Sad/0c2047a0a01355ea6b12de4b051e3704bb86515c0f877b32560efc19.jpg
#   inflating: dataset/Sad/0c204a445c2cb875a60c15ea6c25079ca51f431e4bc9d7d8a0c68fc8.png
#   inflating: dataset/Sad/0c20ad6b1bd541d0632285abd5e3691a1a8064d1142f9519f2a0efe1.jpg
#   inflating: dataset/Sad/0c22f162e385958c28fa7380ac2cc36159197c256a88347000db1114.jpg
#   inflating: dataset/Sad/0c28150a1087d40a7a3b254518b80413e1e6c1760d746789b3b67cd4.jpg
#   inflating: dataset/Sad/0c28217efc66702b595f859f998f281910af5b9f5943ee40ee7d0d7c.jpg
#   inflating: dataset/Sad/0c2ccaeba765420fb8ba5f50548df850eca9d8dcd42dad9db1d53057.jpg
#   inflating: dataset/Sad/0c2d0f6fe3cc06d43d96d547dac96f1b7660d79a40b5783fbb08c759.jpg
#   inflating: dataset/Sad/0c2d754496825482fb7a4341e2344f2726ff6297cd5b71ea2e81d2f6.png
#   inflating: dataset/Sad/0c2e0154bfdc540282a1abc7a151bc86d10454d2301214f7a2bf55cb.jpg
#   inflating: dataset/Sad/0c2e64f2cf69aad8172ac80ef22a427b140a95c62d89836326aa696f.jpg
#   inflating: dataset/Sad/0c2eff42f53190fa52e616f550c768aea0414130b29e7879a243c058.jpg
#   inflating: dataset/Sad/0c31051fcdb993ba90b6ae64b5e598d78974c8774cbd802fd5ed9b87.JPG
#   inflating: dataset/Sad/0c33c1811ade54724a9b6365a68c539571ab88ef4a8641a3d635c50a.jpg
#   inflating: dataset/Sad/0c39c0fa8e331ede9bce762a038ad5cc133886de784c79e6721f3da1.jpg
#   inflating: dataset/Sad/0c3b9a8811282b55197ec37ba80c9ef8078d0555cbd29c51a15b2678.jpg
#   inflating: dataset/Sad/0c3cfa27882e2c17101ec77094c52064eb00f3d8e176566b7b98b4f2.jpg
#   inflating: dataset/Sad/0c3e9a88f533fd10c99a64190aba1a9a711b4158446ad4b3de88612d.jpg
#   inflating: dataset/Sad/0c42081b0f28c2b4f415362decf63bb7dd8d377d3b4017d67aeedc57.jpg
#   inflating: dataset/Sad/0c425f3238985c23b7eec33ce1900097740c56080e2398302005e766.jpg
#   inflating: dataset/Sad/0c4741570963b80c7d118c0fe6f31eb68d090ace8e6d4bf7fa7dffcb.jpg
#   inflating: dataset/Sad/0c4748d2e6165c86350bb14bbe85e08416ee4891a109b95ef6c4ea2f.jpg
#   inflating: dataset/Sad/0c48c58d42fbdebd15632411655b9856978353fea21af53ea90a1d43.jpg
#   inflating: dataset/Sad/0c49c5bc60e671961775280e6d816cea998bc0920fed4bdb9c7398a2.jpg
#   inflating: dataset/Sad/0c4db15aaf69b569a906121386eac47858022dc329922e0990341697.jpg
#   inflating: dataset/Sad/0c54fe22eb00f1355530815c3be34bca2e772c229655dee13f8870ad.jpg
#   inflating: dataset/Sad/0c5eaa33d04dd597574896d3d5258ac6e6abc02104df5722d82da359.jpg
#   inflating: dataset/Sad/0c5ee7ca7513a235c60c5ae5d720062e6cfd83040456676b99e52cdf.jpg
#   inflating: dataset/Sad/0c622824952de613a8b2471c44b1296f6179dc59c02422d37e5bb559.jpg
#   inflating: dataset/Sad/0c684c80d99da97d48d7e34537904792cc05bdb359253ab2c643d895.jpg
#   inflating: dataset/Sad/0c6acc631545be6b4e9b8e09de7034d4e19aca286160b5f7fa76df9f.jpg
#   inflating: dataset/Sad/0c6b2225cf252055cbe2a77e826de74bbc5809ec7dfef8a9797e3dc4.jpeg
#   inflating: dataset/Sad/0c6dc1eaf73a6b95f10f6d374a605e5c7aeab091c83d44b8df5b8089.jpg
#   inflating: dataset/Sad/0c6ef63539d5d167b1d2d0d7a24aa66efa2bf7dba048d59554cebe72.jpg
#   inflating: dataset/Sad/0c6f58690916ba8a5bda1f5cd536150d1a56c4fff14ad788f47fc331.jpg
#   inflating: dataset/Sad/0c72387f4bc07ca495ce515f51e802a0283f8a227762afc378fcb9f5.jpg
#   inflating: dataset/Sad/0c74a3a078b316cebe0048cf2c3a3bc406e51ecfe2e97ac16e6ea885.jpg
#   inflating: dataset/Sad/0c757b4196d4f6a58f69f9d05031b48cb6ed3f75248e86ea98e3b842.jpg
#   inflating: dataset/Sad/0c79de380e1377c651f6c6b86168d93d799d76f63df97c3bc081c6cb.jpg
#   inflating: dataset/Sad/0c818ac7cbb43307bca5407361a5c516e55485fa4e31d5d9d7e77d9d.jpg
#   inflating: dataset/Sad/0c8294fd3ccfcf2d8b4e1ada3c7f0e8f14b57c9b03c6f4ea44bf8bf5.jpg
#   inflating: dataset/Sad/0c8373ff00207b7423366b39574b7f792cabf839b69dabc68a481d04.jpg
#   inflating: dataset/Sad/0c83b8a1fa4e9152c238e2627e928efa79ca4d239c2fdcf81af355ef.jpg
#   inflating: dataset/Sad/0c898390b3e9c3d7948096a0cf28dc70c67e5dc052e698dcf3e9930d.jpg
#   inflating: dataset/Sad/0c8a4dce4fd371d3e881536b61d6db07b32c3b0cdb218fab7260c963.jpg
#   inflating: dataset/Sad/0c8d1e97b7f3bd2da07c3e87acc5671af3aa79d60253345f27607ef8.jpg
#   inflating: dataset/Sad/0c9479c205bbb1cb3be030802ba281539e0c102d9f317c3397e04e94.jpg
#   inflating: dataset/Sad/0c98c88e1dbb32e6eebdaa429120586bb1c0b1c049bec9765d8ab5df.jpg
#   inflating: dataset/Sad/0c998162556aef5029f93dcdc52bee1c00764b677d1fe3a7ed04943b.jpg
#   inflating: dataset/Sad/0c9ae4a3625456aed798d34f3271ada137d756384affa201fdf08204.jpg
#   inflating: dataset/Sad/0c9c7f53eaa3684ca44846b2887dd8d27d8b81df6b04170782232a04.jpg
#   inflating: dataset/Sad/0c9ce1de5a8c660cc254d36b0cad19645aca821f87f546d6e9ecaba6.jpg
#   inflating: dataset/Sad/0c9d9d3c5eacd99d74d6d02d0c7f54e563c1d3ae9be4e281a97c64e3.jpg
#   inflating: dataset/Sad/0c9d9e0b08c8f47977ec21b222e5802e152a7ce2a89b4afe757bf3a7.jpg
#   inflating: dataset/Sad/0c9ec9a73b2b59b96c280d58ada529e67fe75fd1397b64bb9638a579.png
#   inflating: dataset/Sad/0ca031f92e0dd652209fed0372a431e24b80bbd42354683deb541153.jpg
#   inflating: dataset/Sad/0ca67d93dece906a80844918fbe0ac5613c3500bf294ebb799f569bd.jpg
#   inflating: dataset/Sad/0ca6c7a4d0c7512a1bf1bfb518765f03a3564c6f7efe0ee4e09ef722.jpg
#   inflating: dataset/Sad/0ca849eee743043c4ad6c299b2ad8df987db22df0fc6adc53cc3b5d5.jpg
#   inflating: dataset/Sad/0ca8e5a7db84a032e78790bd6e417d6fb184fe9cdb6dd7555a57eddb.jpg
#   inflating: dataset/Sad/0caf75f11a1773b334018fc94ad9fbb7c82cbccde5183ed93577b58f.jpg
#   inflating: dataset/Sad/0cb06bd338dcbcadc1440f692f69af399987ae977e7020fb18e96b82.jpg
#   inflating: dataset/Sad/0cb2c96ae4a87de9d51be2b0c5d2394e46156a2c76dd13e8af897e69.jpg
#   inflating: dataset/Sad/0cb6ea0fc75d291571856186279c79824504222026f6d7ca43d965a1.jpg
#   inflating: dataset/Sad/0cb6f40a2b94f434096dc9f146be8c95c5396f53100f5b0694d9e78b.jpg
#   inflating: dataset/Sad/0cb7e913a1ef21ae57576f21dea5b68f13831f90adcc8f3de357b902.jpg
#   inflating: dataset/Sad/0cb8fb215bae787484627fbed666b3da8ea3f6cd5383558e98650f46.jpg
#   inflating: dataset/Sad/0cb9ec5d9780883a53733db8fe76ec25488c13b10a891434bf1bfd65.jpg
#   inflating: dataset/Sad/0cbcd527bb37bf0542f244255c3d81da2562485b610d1e32bb93c7c6.jpg
#   inflating: dataset/Sad/0cbcdfefab84a913e3152927340f457e5b1feab934673237ff30ea8f.jpeg
#   inflating: dataset/Sad/0cbd4abce6fcc5fb097314fc6be61acc8bd55414fd3e9215d40eb58e.jpg
#   inflating: dataset/Sad/0cbe7b4702f8f34aefe504d870ce470022b99f9794550ab79322a8eb.jpg
#   inflating: dataset/Sad/0cc1c93fb1500e9d20818270aab95213ad92373cd42e0eff22694fd8.jpg
#   inflating: dataset/Sad/0cc74dda8528cc5fc7d6ee9daef05a408910386a7e3c695a24bfbdef.jpg
#   inflating: dataset/Sad/0ccb7c927cb356a557b34c248850d2ab59e96616bd29542f6e1fa7c0.jpg
#   inflating: dataset/Sad/0ccdf64f4478e6196fd5ca7c72e1aee96df8d7c1cb15477809f20482.jpg
#   inflating: dataset/Sad/0cd0fff27c0f8d5410e6a55fbc09b430f8d3314fb695e46501560123.jpg
#   inflating: dataset/Sad/0cd109bf75f9cddff553b4e465f3febcf1cc6fff014d0827d44abffc.jpg
#   inflating: dataset/Sad/0cd12c1e9c47e730443d148961fedd5d33ade4e855c4147bd2673fac.jpg
#   inflating: dataset/Sad/0cd66ba02b94a77955c31ae705bfa1e5852d424f025fc083bf4b7ca7.jpg
#   inflating: dataset/Sad/0cd6ef06e1291364ce8811fae313a72568bfe9a74544255f2ee61bfd.png
#   inflating: dataset/Sad/0cd79ea4467996e72c809ff9f0f4713461b31b0a95a7e3f71e8108b5.jpg
#   inflating: dataset/Sad/0cd7b19f04679b95d352e226fe88f858a2dd21615ea5689c06e6fe0d.jpg
#   inflating: dataset/Sad/0cd9a8bd51de196705e84542ee929b23142b728325f9dee5c4f565fe.jpg
#   inflating: dataset/Sad/0cdffdc1bde33ff846e5254b0a74ba398aa06dc52272780b69a8f731.png
#   inflating: dataset/Sad/0ce08c3e9d32080dadae3baec828a1036b0fc05cdfd231266e3c16c4.jpg
#   inflating: dataset/Sad/0ce2121713da1ac473f191c7d57fb917cf989aa07a08b8dfa4f8784e.jpg
#   inflating: dataset/Sad/0ce29cf436b680c66063730a4f5e7f12a24006358f85288cd228f525.jpg
#   inflating: dataset/Sad/0ce685232e5c277b2246c0816ca57849722a20753fb4ee99467118b5.jpg
#   inflating: dataset/Sad/0cea7194753da0134789ffc69cd680e2e4679357b8e4df35c284ab30.jpg
#   inflating: dataset/Sad/0ceb1ac5a68d0d3db01b7c66f6fec2d66f02fcfe252bbf731340244a.jpg
#   inflating: dataset/Sad/0ceb3cbd6c0b36ead525e52e95d3aa1cd5446ea02b6d38c700ff76e8.jpg
#   inflating: dataset/Sad/0cebb0c751534649249a928ead46d3601109a45ed4696bdbc800e38a.jpg
#   inflating: dataset/Sad/0cf3815332aa1bbf3a69b897458e12da21ed4c02bada354cfd594bdb.jpg
#   inflating: dataset/Sad/0d05b2e08c90bee838eed3f4ea207134e34532df4fc918fc24af7432.jpg
#   inflating: dataset/Sad/0d061d3545f511fb0b1a65afe1a9adeeb37bbee773c75d21e445e82b.jpg
#   inflating: dataset/Sad/0d0664f75e5e6e4985c50cabff4d1512e7e4470fb644a08ec77d14b8.jpg
#   inflating: dataset/Sad/0d0b9cf020bf0c0b82038aff5738cef212e718bee23cefffd2f80b3b.JPG
#   inflating: dataset/Sad/0d19cef96c2f8acb78c61226ac73735ce28f730ef13752fd95ae0371.jpg
#   inflating: dataset/Sad/0d1b19a9ef8fb4da25dfc86822c9f19ae4f7874132c62a9724771d35.jpg
#   inflating: dataset/Sad/0d1c9a391a13ab79d19e4200513771b224cc74be9c8b9e7b94212520.png
#   inflating: dataset/Sad/0d1e9a82ddcae72827871ddc72c49082c7543c2b865fd52438f10187.jpg
#   inflating: dataset/Sad/0d222d5f2f38c9766f8e5b3234da1e3cb778d26b82fb2ea5fa46cd0b.jpg
#   inflating: dataset/Sad/0d279185deb1e553d02c5cd4ab7a7deb3b82393a4fc4ce837c9e4d51.jpg
#   inflating: dataset/Sad/0d2f13da8a39553b98388e1c912f9873fa02734d8097a8d45df943da.jpg
#   inflating: dataset/Sad/0d3a7b8dd295e4dd32525879c1f6845e0e7a06ec4719c6a7149a560a.jpg
#   inflating: dataset/Sad/0d3e2374c03a31ed081e86853c26576ca318c27dcab62173f324a870.jpg
#   inflating: dataset/Sad/0d410409a6a49f8bb8ae313ef70827cfd1b54cc0ce6f9f9621da715e.jpg
#   inflating: dataset/Sad/0d4170d2dd749be66f6ddca46dc0e5078aa95691f09a85644df83be6.jpg
#   inflating: dataset/Sad/0d445b389ad0c2bd40f7992d1dad7379744da20d2ed92e63d23493c3.jpg
#   inflating: dataset/Sad/0d455690e39c1bf77245faa5e80d504af63a3535b6d091a138d7cb35.jpg
#   inflating: dataset/Sad/0d46c779418cc01add0d199e9c7a451d7d4c6d1ad2bfbacfe4bb1ba2.jpg
#   inflating: dataset/Sad/0d4cb064d8293b046603cfd5becaafeecd499f8825b1b2b33051b962.jpg
#   inflating: dataset/Sad/0d55109b3f4691efe26a7f27bb747b13d6f9b2b4fd11e6c01cb937d1.jpg
#   inflating: dataset/Sad/0d558323bff79b4af790659edc59ebf8ee86f914cc72ac3f35abe648.jpg
#   inflating: dataset/Sad/0d580df81456827712941830349517b8e454bb5d42649845218b279a.jpg
#   inflating: dataset/Sad/0d5b8e35c5dd63f51d709a39ebb4c73692ade82093ecf33e5d709a6e.jpg
#   inflating: dataset/Sad/0d5dcbed58ebfa58ff2424c86cbd98419797365573d0344ac668c714.jpg
#   inflating: dataset/Sad/0d5e1a7169f650d6132189cf7100eba6f5201068cf6775cc9c1b29e3.png
#   inflating: dataset/Sad/0d5fb65c5ccfd6643e4b7488ea61477ead2aea565ca9773064df854b.jpg
#   inflating: dataset/Sad/0d6101083c084a1911559b351d9a6e7d2db9bd897a8ca6080d521dba.jpg
#   inflating: dataset/Sad/0d6336af036b9d36859409ccf57e04107a6c4091dc809768d473bc3f.jpg
#   inflating: dataset/Sad/0d66af151216bb2114705f8743280e699c64dff9b3abb3c91c8d5214.jpg
#   inflating: dataset/Sad/0d72039f56baa4a23a69b9e14e0a0408553fb3c9040a0fd4f0194ffc.jpg
#   inflating: dataset/Sad/0d76e3ac4a76787acd2ae414d06e2d6a92075c70db87c1608878df67.jpg
#   inflating: dataset/Sad/0d7b25d24e55c16be1439d76c05fd1369ee131675ce73be7c0821a06.jpg
#   inflating: dataset/Sad/0d7dbb3b026dfe4a915e18fcf685a584f3ee67e29beb236a5da7b5c3.JPG
#   inflating: dataset/Sad/0d7f377f8a1fe48c515d1e8e5f69d54e6547340ecad700f710c0946c.jpg
#   inflating: dataset/Sad/0d82bd7ea30cbe4207cbe4e8c2584c9cb3dc4fe0577bf9eef60878f5.jpg
#   inflating: dataset/Sad/0d8449949a36d5a17b6df21ccae854e457f6d8f5ac53a4d9874b4952.jpg
#   inflating: dataset/Sad/0d92f36df39a18f28eb09ec6437c5c870c230aae62ee7bcdb1fa895b.jpeg
#   inflating: dataset/Sad/0d97444c2a6d12c791644163c06b37d29184263a65afd6b81929e120.jpg
#   inflating: dataset/Sad/0d97518b883ea04f5b39c52489b3960e8b585527168ba05fe02b9722.png
#   inflating: dataset/Sad/0d98d268744012cf185ffc52111af9b169123d0bf97a23c4290d9be3.jpg
#   inflating: dataset/Sad/0d9c1738e6f826c27ac589e2e6071f38cda4d58c0c9070a56dcb1364.png
#   inflating: dataset/Sad/0da28d3252ef6e8066c2120c1a24ab4900f83bb5a7ed5cfaaa45f34f.jpg
#   inflating: dataset/Sad/0db23cf660fff9748d5b37092c5fc13a17d4226ccfc421fdbc450180.jpg
#   inflating: dataset/Sad/0db29306aa805b9a132aef825f359784f61a94e1402966045e536043.jpg
#   inflating: dataset/Sad/0db3df2ea55f10599cca3fcdf85f51c9a08c9e067c50c1956c2aa8a6.jpg
#   inflating: dataset/Sad/0db8e48d62be0fd858ef088919463fc107e6d49e4ee9e7a80e8f5e7b.jpg
#   inflating: dataset/Sad/0db9c1706cfa54589b83e698b13acf6e92257f775429daf867dcea97.jpg
#   inflating: dataset/Sad/0dbc49cb057a95f073ac5bacd6704cbbb0b6c73c945f14fcb3403128.jpg
#   inflating: dataset/Sad/0dbd20ac9c114ed715944f11be9167c24b5e437627676a5d7c223cdb.png
#   inflating: dataset/Sad/0dc0af0b55dbe2741b22d20d97fef90a73adcb6de1efee4f98b39513.jpg
#   inflating: dataset/Sad/0dc2974f3cc61695a0b63bb1f506ec8b19fab279e1b7f15b5f120f15.jpg
#   inflating: dataset/Sad/0dc3419edc0770e7656980ca9840ecb51563fc237ddc662b0bae4dd7.jpg
#   inflating: dataset/Sad/0dcd04c899c7015d02983cb9d31130421f3f23f2a084c00946895063.jpg
#   inflating: dataset/Sad/0dcd559e3fe512d68885cb9c28ffc597c2d5ca7a07cad9088d475151.jpg
#   inflating: dataset/Sad/0dcda4a7f9400d0a1976f12deca774fa271ac3b3853e55e0d01e3e43.jpg
#   inflating: dataset/Sad/0dce7291bb48e980af5fc7d7cb163dd89b777711bdb52790c59e6e50.jpg
#   inflating: dataset/Sad/0dd3b50e984aaeb4fb7a80a1c2692183d07fac4a2eeefb48ac2a6937.jpg
#   inflating: dataset/Sad/0dd7649587a5ea433badf51dbb41d7da4da758dd891ccad4a525fee6.jpg
#   inflating: dataset/Sad/0ddaa3a1145fb36cebff4a4f94ddf6588330abd5519a9e404101456a.jpg
#   inflating: dataset/Sad/0ddedb7ecd605a86e1b84cf75bb66c07f40a9e062a0dbc18fc1a6dae.jpg
#   inflating: dataset/Sad/0de20eaaf3cc2da95bdf13d3b922455e5735fef52ee226b09970f2f5.jpg
#   inflating: dataset/Sad/0de2d45c77a4c5f30c6b536548316cf3d68304bd6708e244eaf62e0a.jpeg
#   inflating: dataset/Sad/0de3045f9a72c1d28cc5ce041dd15d0b7e0f61df9dbeeee95e9134ad.jpg
#   inflating: dataset/Sad/0de3d66514bed70fdf0e25faf820b62933385c788216091735800116.jpg
#   inflating: dataset/Sad/0de40134b25f1e52c24a32ca4f783fb263e1a88d27bc981f528e06ec.jpg
#   inflating: dataset/Sad/0de4e34a55c7ef557f0a5de36f8268a3053b3142b2e02e479b1202c1.jpg
#   inflating: dataset/Sad/0de7dffc083e07a13421faaeef2de5ecb891e57511884d5f783db1fb.jpg
#   inflating: dataset/Sad/0de83fb485a81ac00e6a28bf91bae52cc342bc431cafa9d2d4bcf80a.png
#   inflating: dataset/Sad/0dea83e9fd3deec308bb3427734dde11f76076f237e5adbafcdab832.jpg
#   inflating: dataset/Sad/0deffac7960d2849f245a76c3500a4af4e15686fe303937600902301.jpg
#   inflating: dataset/Sad/0df66f7c014a7292ffcccb3d6912246e8c47a54e3c87bc108f491a3c.jpg
#   inflating: dataset/Sad/0df8df04d7f4dd634883dea193cd3abda3b89c0cfa4a918f7edfe463.jpg
#   inflating: dataset/Sad/0e01974b7ff89ddbc062668e686828162c3a229989282c9ba516d314.jpg
#   inflating: dataset/Sad/0e035c92455dd0b398ee5ca06a9de89ba1c16765f3c0b6d4a2dccb55.jpg
#   inflating: dataset/Sad/0e03dd8e3648667f057d26036e8fea74d174070203cd087fa08c0c5f.jpg
#   inflating: dataset/Sad/0e06c78cf9df26cbe214c7830f629b292743ee0ad45c2ddeedb252d6.jpg
#   inflating: dataset/Sad/0e1224765d87e29b59ca5fbf0258a0376319cd249302952ab5cdbca3.jpg
#   inflating: dataset/Sad/0e1348a4f42691c152a5d28e0ca55c156778bcd9941c4455ae7fe741.jpg
#   inflating: dataset/Sad/0e142be1ceb1fe298f7adb9ffff49363b9d509aa09347e11266a2108.jpg
#   inflating: dataset/Sad/0e18b1e9a78877a5fa30cbb77895247a2c5a5dd777514478fd733ea0.jpg
#   inflating: dataset/Sad/0e233317fbbd806eb3378e86a1fc4e67c9ee8f3645864a2f1451f661.jpg
#   inflating: dataset/Sad/0e2c9fb0f2fb2592c14f527467321ae4cf34825ff84de362f9b88402.jpg
#   inflating: dataset/Sad/0e2db9916bbacce66a468021f37508bfcfaccafa658f60bf1a0a0a24.jpg
#   inflating: dataset/Sad/0e33d51f7d34b81c1ec27d1ff072ee59528ae99c1e8dff25e3be40ea.jpg
#   inflating: dataset/Sad/0e374d227ece80cfa4e616c460205617d23ef5e1704dd94cc70f9334.jpg
#   inflating: dataset/Sad/0e3a0db7374ad3b2b0c190ff2aec26ccc40ca4a737e1fcfa872cc190.jpg
#   inflating: dataset/Sad/0e4222abc8aca3fa9979b90922331a1cf312324b3a295f0d9c3f0dcb.jpg
#   inflating: dataset/Sad/0e45b2ca50ac8ea3a6e925275359fccb33c178fbd886469962f23ccc.jpg
#   inflating: dataset/Sad/0e4b047da4a64e825e9e7693b92fb1d14dbebf315cce2b5e1390f079.jpg
#   inflating: dataset/Sad/0e4c002e9eef2cbf27420a2026408f11d002fe0c05d4066dda9cc2a9.JPG
#   inflating: dataset/Sad/0e4c6a5c89ec4123f89f36e0d481cb97a45b2bc09b03b57c7d27a947.jpg
#   inflating: dataset/Sad/0e4f3b68a14b49505aaecedc36992121e2b7d70c73277f744caaff2f.jpg
#   inflating: dataset/Sad/0e4f65b1a0d0e29d10fbc35116f1dc07506c6acdeee578ab5db54afb.jpg
#   inflating: dataset/Sad/0e5473d6a57c3793f9c4f25bb82215f3cdb3c97b8e18947e5f84bc99.png
#   inflating: dataset/Sad/0e571de67d0e63e344ecbdaac64447d675b47165df6eb7e0b5563472.jpg
#   inflating: dataset/Sad/0e5f3e970285eee065a4a36e90c4b0e0fb9c8bbebefa850646ca0a3c.jpg
#   inflating: dataset/Sad/0e644a89cf7be6a07ef999250dc139185dd7749ae1a8116f11c07f39.JPG
#   inflating: dataset/Sad/0e698a2ce43471ff79724f3a38e32e1ee738e4adced3ffec95d88397.jpg
#   inflating: dataset/Sad/0e69e2b369a08d4beb6b8e310b1c9e9e121ef7a266731d0ff5a1db78.jpg
#   inflating: dataset/Sad/0e6b38eba7f4625ac324b443259572a8eaf145f3056fb62fee3b8a6d.jpg
#   inflating: dataset/Sad/0e6f3b7d0ddd6acb27ea612372b83ac066cd3e0bae4239f63d2b7ca3.jpg
#   inflating: dataset/Sad/0e702180d1ef38ee338624d4abd06de6c54b7566cd9cd6bcc64fb247.jpg
#   inflating: dataset/Sad/0e72292e4f0d72704e2ca98973cff130ffdb2951e262d9b99b290615.jpg
#   inflating: dataset/Sad/0e735473adb1318fa37bd58519ec0be7e1d8b87587168a88a8cb8000.jpg
#   inflating: dataset/Sad/0e7537a31d02c4061723c4b46aa5ba7d73f1537f2d0a6cd3fca35798.jpg
#   inflating: dataset/Sad/0e78855c78b2d0526a8aafc19bac044c701dec477d4aecb31f14bf5e.jpg
#   inflating: dataset/Sad/0e78c5a4406a7979b8234c47625d612f44730aac846e8ca473fd2253.jpg
#   inflating: dataset/Sad/0e7bb207f2bfa650e7121d2b25badac7314f96a6d9f2a0882bfd8237.jpg
#   inflating: dataset/Sad/0e7c4aef73e9cb1dc1f611cde8216faa6e7dfcdcb59d170d526e3a5c.jpg
#   inflating: dataset/Sad/0e7c52c9e64b40996989ca25a4826930142f49d9b83dc36b6f8179e0.png
#   inflating: dataset/Sad/0e8079cb5bfb84273b822945f11e5e0dd9e75921cf4ea0b7e0f0003e.jpg
#   inflating: dataset/Sad/0e8556a79cdde80c6a7516c60f42d9be6eab6e4ae341f88c11b0763f.jpg
#   inflating: dataset/Sad/0e8f8ea90593e6dd62d8739b5d902252aa41079814d6435cc768be55.jpg
#   inflating: dataset/Sad/0e903494bcec58a38577b99742c613937a21ce301e73fe5b87355983.jpg
#   inflating: dataset/Sad/0e9105dbfd7d8f1c25d2fb59bebb2a0277bdbc7605dcb7442eed3ee5.jpg
#   inflating: dataset/Sad/0e93279e60eb865d831e349c32b21fee0237d9f533a05b3d2ece4999.jpg
#   inflating: dataset/Sad/0e95c0dda8ca11e8683e28e8d0c0a97460c594a10bab23efd4a7b55f.jpg
#   inflating: dataset/Sad/0e98624754ba269b7d6702009b16df741b46189dee0332278e61ed4b.jpg
#   inflating: dataset/Sad/0e9d42be2d8270a1e0a4b4af399cb9ea4600f950f676363634053800.jpg
#   inflating: dataset/Sad/0e9db094380fb3c26887fd8e142e407f892aab174a3d3834fcf3dc4f.jpg
#   inflating: dataset/Sad/0e9e145698f81a7e2e7a163ab7e416dfeae0eb075e7a66bfaff94e98.png
#   inflating: dataset/Sad/0e9e868f405e040f4a86ead08e66641f7a26d9aba24ed68313a80ce3.jpg
#   inflating: dataset/Sad/0ea8c1804c4f037a776b1f61a04a004618b4121b9a269d39fb3aa1fc.jpg
#   inflating: dataset/Sad/0eab0383a1f7675e614e5d9a459831eef6f9cb0942014d72e133ed06.jpg
#   inflating: dataset/Sad/0eab0fee8670a8d4eeba41b03240d31bc3e2c18f531759a97a708a14.jpg
#   inflating: dataset/Sad/0eb3e049407b5501fc4dcbb78dbe39eeab0a6b466cb14d8b78cd8286.jpg
#   inflating: dataset/Sad/0eb4844312c24bfa4a239ce1c7712502bae0cb898bb61115dc6fe858.jpg
#   inflating: dataset/Sad/0eb661eb1913a6264c4492707d1e91be4c158c57844254c3d2259bfe.jpg
#   inflating: dataset/Sad/0ebdf516cf78f073ae2ad07f9117249e4642bc970771b34b06fcf1ae.jpg
#   inflating: dataset/Sad/0ec2cfb73dc1a1a72b184404bdeeeb2cc7226ab549cdec9ae67ee895.jpg
#   inflating: dataset/Sad/0ec3e066cdc09d1d6481777491945231ab2d51de6f25fcff6b61fc6f.jpg
#   inflating: dataset/Sad/0ec5e36ac912fd3cd6e6c6a8c72c797d62ea60c11adb8366f2cbcb38.jpg
#   inflating: dataset/Sad/0ec65aa9abca2afdea2bedad518bd7ff7ee463b89cedbdbffbe69931.jpg
#   inflating: dataset/Sad/0ec8723a4da2d772433fd4ff604ed4edf137a634bb1a07a23ade73d5.jpg
#   inflating: dataset/Sad/0ec8d64d29dcc0a83c191b963812275196550af3ccf7e686c9220a97.jpg
#   inflating: dataset/Sad/0ecb2c4e6a8111f6cf3938cd867dec2ddb05bc9c5f1be163f418b754.jpg
#   inflating: dataset/Sad/0ecd07277236e9b6266a9cdc413c5be7a70572650314bd71cc351eb4.jpg
#   inflating: dataset/Sad/0ed01c5127918c75979f5613dd7561358d0f2b29b9d121360be008cd.jpg
#   inflating: dataset/Sad/0ed06e02daa5ec346f560ff669d5de8dc6648c2535fa7fbd35d4d9fd.jpg
#   inflating: dataset/Sad/0ed84646c7939212d4b2c47784ffb1b7a33fd6b4628a2117791c53cc.jpg
#   inflating: dataset/Sad/0edc98f24f04e0d27c6f0f81f039dce61021f0a04281eedc6e3f73e1.jpg
#   inflating: dataset/Sad/0edfa9acbb64d2183a4141daa40e873a013c560a069aa2da554eff80.jpg
#   inflating: dataset/Sad/0ee1fe03061d5af8aa0884b174b1d6c7ce400b14555f787a3d77541a.jpg
#   inflating: dataset/Sad/0ee3b65c5310655e048e1a314e69a4edfda4c4ded4c56c1170dd54b4.jpg
#   inflating: dataset/Sad/0ee4e0489f58e9db1a792a2868a5a6d9789783313a8d50c42d619f17.png
#   inflating: dataset/Sad/0ee5c13473789f7c4a1efe8d61a1d3402338d143d68951b1884f4555.png
#   inflating: dataset/Sad/0ee6ee62a9c4b0cf0cffe7e9ce3a19ffca0483a9973e689f8cc0b046.jpg
#   inflating: dataset/Sad/0ee86106be17d60cd562866674efe4fd901e2ea60c4b7f835fe7d90b.jpg
#   inflating: dataset/Sad/0eef1eff147334814f5428ea9ca2a916260dfa41ac8a6e60a4c2353c.jpg
#   inflating: dataset/Sad/0ef12d63310cda78890803f1a79494889bee4356f9df09adb314c966.jpg
#   inflating: dataset/Sad/0ef34b54aef11f1120b149f04182422ef524c0ce0aea353c2179b10a.jpg
#   inflating: dataset/Sad/0ef37535af65819a10d02e31cd9f4c20ecc90cb7ceb2435dc90016dc.jpg
#   inflating: dataset/Sad/0ef3dd413204bd1879db82cd284fc0afde528b06b6a94030f49608fd.jpg
#   inflating: dataset/Sad/0ef73679fca510747722accc027d410a0d57e0d86955ed6cdb225227.jpg
#   inflating: dataset/Sad/0efa15a016e86f6fb5413c163eb0d55049cd5d5d5d0004ae20c2a843.jpg
#   inflating: dataset/Sad/0efbebbaaff6ed50cc6e52bd2eaed43a0d3fb25bf002fd0c1973ef3a.jpg
#   inflating: dataset/Sad/0f0075fae2bf9dd5fa3a659879723a88b21633bed73d59b9230be19d.jpg
#   inflating: dataset/Sad/0f0485f71c14ff380ba453c790ba22275322458ca10b651c55d2f5b1.jpg
#   inflating: dataset/Sad/0f0632c0eeffbdcab8979f61119dd4f04441784ecfe411da3e99bdc3.jpg
#   inflating: dataset/Sad/0f09466ec64ce84dd9b180aeebfff0a81b7c7ec48207d0df775f2870.jpg
#   inflating: dataset/Sad/0f0ad3b5b8c88bfa3445c21d12d4500262e3cabb2f2b77ab07f1c7a9.jpg
#   inflating: dataset/Sad/0f0effbead57cdd1fe07a32cabf03381f63feca90f8a7fe45898f76e.png
#   inflating: dataset/Sad/0f1400a4403e66ad7a927df634186d37576c43636d7af0044da708e0.jpg
#   inflating: dataset/Sad/0f15084324d40519f34f55a22c40d4be0c6080c091f19416964269bc.jpg
#   inflating: dataset/Sad/0f151d34b9897bb1c4b953f94544b78db79a8e2b5f9162915f2b1e49.jpg
#   inflating: dataset/Sad/0f15bca04a169ea22a024090d3687464ff6b4b1f097e504b1c39fcf2.png
#   inflating: dataset/Sad/0f162d731b8541405c3c5cf5a1d88f45c8be5e2e5bfdc8aabb2a594c.jpg
#   inflating: dataset/Sad/0f1d3695cc425dcdcdb86155986d4c6fa83426cfcf37222954818d10.png
#   inflating: dataset/Sad/0f21d32dd81123b5281da3fcce95f6e8e3d2ab12ed5639e07319d24e.jpg
#   inflating: dataset/Sad/0f2303bf80e0e55511cd362a49d03c75ed6ad52cfe73f230c62220b9.jpg
#   inflating: dataset/Sad/0f2514d4b23c469317b8a4a4fdd104cf0f76c8aa3352ecb6fc170265.jpg
#   inflating: dataset/Sad/0f2910df9bb006c82cef25174ccb1ed55fdd2e0a859379ca3ea890be.jpg
#   inflating: dataset/Sad/0f2b6f996bb4adb82a55d76700bc4d257e9ba6cad4c9773a1970191c.jpg
#   inflating: dataset/Sad/0f2feeb60649c76e0fcbd29300f6183aa0d7d561810602e9f59008ec.jpg
#   inflating: dataset/Sad/0f3178bdde64110f343f21d15d0a100f5c6eae6d34273928b07ceb91.jpg
#   inflating: dataset/Sad/0f3ec52dab18447a2e01d14f4ff66a9af55409c7b067bd8b6e6cc89c.jpg
#   inflating: dataset/Sad/0f4091f0cc8378f89b404b437275f41ba4ddaeb412f1263235ba8140.jpg
#   inflating: dataset/Sad/0f420dba3874b365295f64592e7385f8e4772912b0a38f2dbdaab2a3.jpg
#   inflating: dataset/Sad/0f442332e9836f3256669a04817cc31e95cb886b2bfaef0835ce7dc6.jpg
#   inflating: dataset/Sad/0f49671f078d3651095c5a6aa6385d9b8140b83b29332abf8602f60c.jpg
#   inflating: dataset/Sad/0f4be0dfdf8ba80b35807d0039459b4606b4ec234c6ad94dd9413ad9.jpg
#   inflating: dataset/Sad/0f4cbf522c34aada737cd3957bdd67d3f584b1324a6955aa0fefd753.jpg
#   inflating: dataset/Sad/0f4e19e11716db5b43c67bb093a1c33438f6f23ea165154731a1ac69.jpg
#   inflating: dataset/Sad/0f4efdbca9c931dee49a7738d2591eda6e24757bbec638d752eeeaf9.jpg
#   inflating: dataset/Sad/0f54886f89933ec64ed96f4d955c350c0f119dfdc4d5eb7de4b58da5.jpg
#   inflating: dataset/Sad/0f5efc8625c3da92f9d565bdcdf4a3308ffbb0573e1d7beb1a92a4cd.jpg
#   inflating: dataset/Sad/0f62db4c370f93b9f2aed468b131dee62d27015508eaf2eee6faf1f5.jpg
#   inflating: dataset/Sad/0f648516b1eea61e7124cf54b95d2b89af898fed1609443ee71870b5.jpg
#   inflating: dataset/Sad/0f650457e3ddb18ff6bdef160ac7e368e3ec5441d3143f08cb3c9698.jpg
#   inflating: dataset/Sad/0f7e0ca3c86fa736e02d1d78eb1492eb89e04cbe716a6e02641243a4.jpg
#   inflating: dataset/Sad/0f8522c531712ada32fdfb5fb275d6b8f22309e53640e57ccdab60fc.png
#   inflating: dataset/Sad/0f881e4642517d5c4c97679248b3d760310085214d7adfcfc584a192.jpg
#   inflating: dataset/Sad/0f89bae038cd46a87cd5e61a4c621ae26ca857595560cc674488a36d.jpg
#   inflating: dataset/Sad/0f8f22a4ed6680ccd5ef62d04de167d6be18012143faf7807cf53a0f.jpg
#   inflating: dataset/Sad/0f975ec011f9336751e08cf331611f2fd2d1dda9b85bd1cf968751ea.png
#   inflating: dataset/Sad/0f981d64a3de013e5df99d12a991bdd0fa75230e6d5715b4e92f8348.png
#   inflating: dataset/Sad/0f9aa7df47d1ac31f8e7d344d8208d00546bb1403aac493f4834c578.jpg
#   inflating: dataset/Sad/0f9e1b83322a94c1761c6e98d5941252d67ab8859ea38fca56a0ad8a.jpg
#   inflating: dataset/Sad/0f9f31f0e113d7c52660ec6f7fffbed8909906f5c768bf1abeffb532.jpg
#   inflating: dataset/Sad/0fa04df65a082747d5f174b6aa698c8e512df65ab74474c6afa83a0f.jpg
#   inflating: dataset/Sad/0fa539d8e13acec296cf4b00e0c6c705eb75a69e6c9a328b6e6d420a.jpg
#   inflating: dataset/Sad/0fa67541c1c62d53b43fe0e881ff5cfbafdf97d4ba8583559378fff1.jpg
#   inflating: dataset/Sad/0fa7fdf7899bfb8220e3f178f7095dc56580de4544ea158af5559469.jpg
#   inflating: dataset/Sad/0fa825150ce7ab38f3d43f986b92801e4bd66d41d87fab38faf1ec3c.jpg
#   inflating: dataset/Sad/0fac9d9f95b56441fc16d909ff96e4bcf9ad50fd77e6819103046b75.jpg
#   inflating: dataset/Sad/0fb1f656de51a1bb9ecd0a9246f7619ce47489d6ab458b0ec7a0b0e5.jpg
#   inflating: dataset/Sad/0fb2c84659b17fe879f530cd0920a3115866f057cbff28e8cb3f45e5.jpg
#   inflating: dataset/Sad/0fb3c29e234cfa35283e300d5142a867104d096d566c7f7b3303a4e4.png
#   inflating: dataset/Sad/0fb682fcd6f6e7c5fcf693dd96cc6afb80b5dfe6102148483d00fbd9.jpg
#   inflating: dataset/Sad/0fb72dffb1d22c2d01f7598201a93b5ae60ecd765846f82f41af854f.png
#   inflating: dataset/Sad/0fb8629ba82cbb1590ce9a152873f5306c1eb63d1d8598a01c30d675.jpg
#   inflating: dataset/Sad/0fb8799a013eacc097bb029a13a01f471fb5de8c74295ae446ba3250.jpg
#   inflating: dataset/Sad/0fbbc4ef35a1366a327b5493919411f54cab3cc772fbbdfc58844032.jpg
#   inflating: dataset/Sad/0fc2e004f0dd640911efb47f1dd41986f54f5ba9c8659e39eee432f0.png
#   inflating: dataset/Sad/0fc72ab9cf84b1392062d041cd172800d9ec6aa3bae78587c86de0df.jpg
#   inflating: dataset/Sad/0fc93e62a9b300c244d164d68127c5e430b4d42e537f018c68b99bbb.jpg
#   inflating: dataset/Sad/0fca5782ce908988d5788dd5fd90f0edbdd6441dd00835bcdf46b13a.jpg
#   inflating: dataset/Sad/0fcfd8eb96a0cf88b3b0d8479140ba23b78a4405b97f572e1fdcd449.jpg
#   inflating: dataset/Sad/0fd0bc67a35763b2b246a732a8d96e657e2118e8b5bb1390d8c6ad49.jpg
#   inflating: dataset/Sad/0fdf17f54db3be3d419066ca8ab47557fd1b78a1e0c3bbdfcc9a6a44.jpg
#   inflating: dataset/Sad/0fe071705e28a88836cd97a6798077d37825caae8aa7d846236c8e84.jpg
#   inflating: dataset/Sad/0fe0b7a7c9ad52dd52d2e98761b5bcd3756657be2e08ccaac088a69d.jpg
#   inflating: dataset/Sad/0fe200ab563eed93f8b0b685682128b7d65799eddd5514503726f7de.jpg
#   inflating: dataset/Sad/0fe206ad68543554a83e65939d7eea14a97df67826051530bc0877da.jpg
#   inflating: dataset/Sad/0fec983076b82651391aff5712a3801a234d9d0fe3cbe894549a26e6.jpg
#   inflating: dataset/Sad/0ff63b79dab958fada6d2e53b5eb008943666aacc9cdda19d106523b.jpeg
#   inflating: dataset/Sad/0ff6f56208ddca209a3e469ce12fc6a7afd1f15ecb2ce88ca1848f98.png
#   inflating: dataset/Sad/0ffa48335ac35509ca807be03c3db625d12b8161b15e8610156e763f.jpg
#   inflating: dataset/Sad/0ffc8676f03c170845e87f256127d1287fb7f8769a175a6a439b6a86.jpg
#   inflating: dataset/Sad/0ffe1e321a894e0416b80a68d2cbed0d2f6ee82dc7c396ffa48118f7.jpg
#   inflating: dataset/Sad/0ffe275a8fc99c3d4709788c12c5dc43abb0dfe0856c939d66f49a42.jpg
#   inflating: dataset/Sad/1a0f277f8702d2a3eb1b4917b9013944100ee02d43e24ffb8684b0dd.jpg
#   inflating: dataset/Sad/1a12b6983dac36c7e6c1bc83216d3367e51f2e1e47d534272d8833b7.jpg
#   inflating: dataset/Sad/1a13fc6d03e7cf6fefb9341ee34a8072dc0d82eeb7a13c69a1c46e8b.jpg
#   inflating: dataset/Sad/1a13ffdbbd46b0a2ab13c032240902fa9504401645df2ec79a9dabb7.jpg
#   inflating: dataset/Sad/1a153bd10817db16bf4614f692c614847fdeff629558b7a3bc40c6aa.jpg
#   inflating: dataset/Sad/1a16ba6a58d85ccc85b735171be8ca1d9ac99507a72c43b7780636fc.jpg
#   inflating: dataset/Sad/1a1db80f7ca3fa4eb73f9818644baf93dc77d10ad46150609dbdc13a.jpg
#   inflating: dataset/Sad/1a1fa3ef58b49b65200e9241d8db18b675ec606fd78f667e1d9a4176.jpg
#   inflating: dataset/Sad/1a2647c75a4446baeef8894217e0116e6672acd07210b9c1b2256d48.jpg
#   inflating: dataset/Sad/1a2686119f74b19dba18077abccad83385fefcf61ab8b3b7f37274ee.JPG
#   inflating: dataset/Sad/1a286e30a028ac4cdecb7538d50d94d01968e94f3cb308d06d84fac2.jpg
#   inflating: dataset/Sad/1a298639ebe59217c5b5708a41ec26207566403c3f39ec9eaa68306e.jpg
#   inflating: dataset/Sad/1a2eaae0eee4a8064cf191cef4a3fb6ac3f5503a7f32f221507e6c8b.jpg
#   inflating: dataset/Sad/1a35220f67009fe57cac4e0fe4e53f0e606c38dd8835f120b5d10ebd.jpeg
#   inflating: dataset/Sad/1a365345765c969725d757948e560bcc13d73747cb232921b1a8d9c5.jpeg
#   inflating: dataset/Sad/1a3dff93989aa1058ec4c0fa722defff3acb429fe9eeccffbe90c67b.jpg
#   inflating: dataset/Sad/1a3e0219ee448996f03c93b0f9603f93ad9c98a753d319274631acb9.jpg
#   inflating: dataset/Sad/1a3f47aa202a156f9b7905ada46203fe7222a7e984e3e9ed626026d3.jpg
#   inflating: dataset/Sad/1a3fb9a47ed1a07792b9c82018585bb5f8eb9cc6224ba7b098abe135.jpg
#   inflating: dataset/Sad/1a435d06f449a39038e0325f7bbfa6cc39a81dca4740a068bf5947cb.jpg
#   inflating: dataset/Sad/1a4a1d20bd7748854ef8a5846dc6727c356dc1847ad64854a14dac10.jpg
#   inflating: dataset/Sad/1a4e11f364a991849475a4544df0a8f1f8452746408d9219e50551c5.png
#   inflating: dataset/Sad/1a51376a2c6d5cced6e0481199bda3a9de6ab4fe261bfd8f3130407c.jpg
#   inflating: dataset/Sad/1a517745e16270720dc68a833ec73385ad6586a21f9b09c62ad761bf.jpg
#   inflating: dataset/Sad/1a5195da66ffd511df255249933bedb2ecf2374d309e2870cbbd8808.jpg
# ...
#   inflating: dataset/Surprise/cropped_emotions.268288~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268304~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268305~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268322~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268323~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268334~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268347~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268364~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268377~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268378~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268401~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268410~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268418~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268427~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268441~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268467~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268481~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268482~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268490~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268505~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268506~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268525~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268536~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268538~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268539~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268542~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268544~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268550~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268552~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268553~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268554~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268559~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268560~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268564~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268568~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268569~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268570~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268584~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268597~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268624~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.268651~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.269276~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.269294~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414833~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414834~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414836~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414837~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414838~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414840~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414841~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414842~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414843~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414844~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414846~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414847~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414850~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414851~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414852~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414853~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414854~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414855~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414856~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414857~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414858~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414859~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414860~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414863~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414866~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414867~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414869~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414870~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414871~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414872~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414874~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414875~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414876~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414878~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414880~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414882~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414883~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414884~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414885~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414886~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414887~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414888~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414889~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414890~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414891~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414892~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414893~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414894~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414896~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414900~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414901~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414902~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414904~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414905~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414906~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414907~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414908~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414909~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414910~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414911~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414913~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414914~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414919~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414920~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414921~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414922~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414924~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414926~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414927~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414928~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414930~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414931~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414932~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414933~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414934~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414936~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414937~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414938~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414939~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414940~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414942~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414943~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414944~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414945~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414946~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414948~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414950~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414951~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414952~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414953~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414954~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414955~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414956~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414959~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414960~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414962~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414963~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414964~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414965~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414966~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414967~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414968~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414969~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414970~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414971~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414972~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414973~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414974~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414975~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414976~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414977~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414978~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414979~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414980~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414981~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414982~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414983~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414984~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414985~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414986~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414987~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414988~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414989~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414990~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414991~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414993~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414994~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414995~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414996~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414997~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414998~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.414999~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415001~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415002~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415003~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415004~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415005~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415006~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415007~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415009~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415010~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415011~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415012~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415015~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415016~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415017~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415018~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415019~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415020~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415022~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415023~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415025~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415026~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415027~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415028~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415029~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415030~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415031~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415033~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415034~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415035~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415037~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415043~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415044~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415045~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415047~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415048~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415050~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415051~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415053~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415054~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415055~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415056~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.415057~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99977~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99979~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99980~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99981~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99982~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99983~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99984~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99985~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99986~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99987~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99988~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99989~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99990~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99991~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99994~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99995~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99996~12fffff.png
#   inflating: dataset/Surprise/cropped_emotions.99999~12fffff.png

# %%
import os
import shutil
import pandas as pd
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tqdm import tqdm
from PIL import Image


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import tensorflow as tf
from keras.utils import load_img, img_to_array
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical


from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# ## Data Preprocessing Steps: Repitition from Preprocessing notebook

# %%
# ----------------------------------------------------------------------
# remove ahegao folder and records from labels
# ----------------------------------------------------------------------


def remove_emotion_folder(dataset_folder_path, emotion, labels_csv_file):
    emotion_folder = os.path.join(dataset_folder_path, emotion)

    if os.path.exists(emotion_folder):
        shutil.rmtree(emotion_folder)
        print(f"Removed [{emotion}] folder.")

    # Filter out rows with 'ahegao' in the 'emotion' column
    df = pd.read_csv(labels_csv_file)
    df = df[df['label'] != emotion]
    df.to_csv(labels_csv_file, index=False)

    print(f"Removed [{emotion}] records from the CSV file.")
    return None



def flatten_data_folder(dataset_folder_path):
    # Create a new folder to store the flattened images
    flattened_folder_path = os.path.join(dataset_folder_path)
    os.makedirs(flattened_folder_path, exist_ok=True)

    # Iterate through each emotion subfolder
    for emotion_folder in os.listdir(dataset_folder_path):
        emotion_folder_path = os.path.join(dataset_folder_path, emotion_folder)

        # Skip if the path is not a directory
        if not os.path.isdir(emotion_folder_path):
            continue

        # Iterate through each image file in the emotion subfolder
        for image_file in os.listdir(emotion_folder_path):
            image_file_path = os.path.join(emotion_folder_path, image_file)
            destination_path = os.path.join(flattened_folder_path, image_file)

            # Skip if this image has already been copied to the root destination folder
            if os.path.exists(destination_path):
                continue

            # Copy the image file to the root folder
            shutil.copy(image_file_path, destination_path)

        # Finally, remove the emotion folder
        if os.path.isdir(emotion_folder_path):
            shutil.rmtree(emotion_folder_path)
            print(f"Moved images from '{emotion_folder}' folder into {flattened_folder_path}.")
    return None

def get_image_dim(image_path):
    with Image.open(image_path) as img:
        return img.size # returns (width, height)


def add_pixel_dimensions(df):
    """ Adds columns for image pixel width and pixel height for each image
        in the labels dataframe.
    """
    # for error catching in case you run this twice
    if 'width' in df.columns and 'height' in df.columns:
        df = df.drop(columns=['width', 'height'])

    image_folder_path = os.path.join('data', 'dataset')
    widths = []
    heights = []

    # use tqdm to make a progress bar while it works through the df (without the timer part of the bar)
    for index, row in tqdm(df.iterrows(), total=df.shape[0]):
        image_path = os.path.join(image_folder_path, row['path'])
        if os.path.isfile(image_path):
            with Image.open(image_path) as img:
                dims = img.size
                widths.append(dims[0])
                heights.append(dims[1])
        else:
            widths.append(None)
            heights.append(None)
            print(f"Warning: Image not found at {image_path}")
    df['width'] = widths
    df['height'] = heights
    print(" -> Finished adding image dimensions to the dataframes.")

    return df

def encode_label(df, encoder_dict):
    """returns df where label column is encoded"""
    df['label_encoded'] = df['label'].map(encoder_dict)
    return df


def clean_up_labels_file(file_path: str, label_dict):
    # Load the CSV file into a Pandas DataFrame
    df = pd.read_csv(file_path)

    # Modify the 'path' column to exclude everything before the '/'
    df['path'] = df['path'].apply(lambda x: x.split('/', 1)[1] if x.find('/') != -1 else x)

    # drop the unused index column
    if 'Unnamed: 0' in df.columns:
        df = df.drop(columns=['Unnamed: 0'])

    # add image width and height
    df = add_pixel_dimensions(df)

    # encode the labels as
    df = encode_label(df, label_dict)

    # crate a new labels csv file
    df.to_csv(file_path, index=False)
    return None



def isolate_cropped_images(input_file_path: str, output_file_path: str):
    # Load the CSV file into a Pandas DataFrame
    df = pd.read_csv(input_file_path)

    # only include the cropped images (they all have "cropped_emotion" in the filename)
    df = df[df['path'].str.contains('cropped_emotion')]

    # crate a new labels csv file
    df.to_csv(output_file_path, index=False)
    return None

# %%
# ----------------------------------------------------------
# Define the path to the dataset and the CSV file

IMAGES_FOLDER_PATH = os.path.join('data', 'dataset')
LABELS_PATH_full = os.path.join('data', 'data.csv')
LABELS_PATH = os.path.join('data', 'data_cropped.csv')

LABEL_ENCODE_DICT = {
    'Happy': 0,
    'Sad': 1,
    'Angry': 2,
    'Surprise': 3,
    'Neutral': 4
}
# reverse of the label_encode_dict
LABEL_DECODE_DICT = {v: k for k, v in LABEL_ENCODE_DICT.items()}

# ----------------------------------------------------------

# %%
# call functions to clean up dataset

remove_emotion_folder(IMAGES_FOLDER_PATH, 'Ahegao', LABELS_PATH_full)
#remove_emotion_folder(IMAGES_FOLDER_PATH, 'Neutral', LABELS_PATH_full)

flatten_data_folder(IMAGES_FOLDER_PATH)

clean_up_labels_file(LABELS_PATH_full, LABEL_ENCODE_DICT) # Note this step takes a while as it opens every image file to record its dimensions.

isolate_cropped_images(LABELS_PATH_full, LABELS_PATH)
# Out:
# Removed [Ahegao] folder.
# Removed [Ahegao] records from the CSV file.
# Moved images from 'Neutral' folder into data/dataset.
# Moved images from 'Sad' folder into data/dataset.
# Moved images from 'Angry' folder into data/dataset.
# Moved images from 'Happy' folder into data/dataset.
# Moved images from 'Surprise' folder into data/dataset.
# 100%|██████████| 14248/14248 [00:03<00:00, 3674.22it/s]
#  -> Finished adding image dimensions to the dataframes.

# %%
import matplotlib.pyplot as plt

def show_class_distribution(labels_csv_path):
    # Load the CSV file into a Pandas DataFrame
    df = pd.read_csv(labels_csv_path)

    # Count the occurrences of each emotion
    emotion_counts = df['label'].value_counts()

    # Create a bar chart
    plt.bar(emotion_counts.index, emotion_counts.values)
    plt.xlabel('Emotion')
    plt.ylabel('Count')
    plt.title(f'Distribution of Emotions')
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
    plt.tight_layout()  # Adjust layout to prevent labels from overlapping
    plt.show()

    return emotion_counts


# Call the function to show the class distribution
emotion_counts = show_class_distribution('data/data.csv')
print("\nTOTAL IMAGES:", sum(emotion_counts))
print(emotion_counts)

emotion_counts_cropped = show_class_distribution('data/data_cropped.csv')
print("\nTOTAL IMAGES:", sum(emotion_counts_cropped))
print(emotion_counts_cropped)
# Out:
# TOTAL IMAGES: 14248
# label
# Neutral     4027
# Sad         3934
# Happy       3740
# Angry       1313
# Surprise    1234
# Name: count, dtype: int64
# TOTAL IMAGES: 5337
# label
# Neutral     1154
# Surprise    1147
# Happy       1090
# Sad         1076
# Angry        870
# Name: count, dtype: int64

# %%
# print this out as a reminder:

print(f"{IMAGES_FOLDER_PATH = }")
print(f"{LABELS_PATH_full = }")
print(f"{LABELS_PATH = }")
# Out:
# IMAGES_FOLDER_PATH = 'data/dataset'
# LABELS_PATH_full = 'data/data.csv'
# LABELS_PATH = 'data/data_cropped.csv'

# %%
# create a dataframe for the labels (y)
labels = pd.read_csv(LABELS_PATH)
labels.head()
# Out:
#                                   path     label  width  height  label_encoded
# 0  cropped_emotions.100096~12fffff.png  Surprise    224     272              3
# 1  cropped_emotions.260779~12fffff.png  Surprise    215     357              3
# 2  cropped_emotions.263616~12fffff.png  Surprise    381     493              3
# 3  cropped_emotions.263141~12fffff.png  Surprise     74     135              3
# 4  cropped_emotions.100252~12fffff.png  Surprise    159     194              3

# %%
# ----------------------------------------
# 4:3 ratio
# IMAGE_SIZE = (160, 120)

# 3:2 ratio
IMAGE_SIZE = (180, 120)
# ----------------------------------------

def image_crop_and_resize(image_array, target_size):
    """
    Crop and resize an image (input as an array) to a target size.
    """
    # Calculate cropping dimensions to maintain the target aspect ratio
    h1, w1 = image_array.shape[0], image_array.shape[1]
    target_aspect = target_size[1] / target_size[0]
    aspect = w1 / h1

    if aspect > target_aspect:
        new_width = int(target_aspect * h1)
        new_height = h1
    else:
        new_width = w1
        new_height = int(w1 / target_aspect)

    # Calculate cropping box
    left = (w1 - new_width) // 2
    top = (h1 - new_height) // 2
    right = left + new_width
    bottom = top + new_height

    # Crop the image
    image_cropped = tf.image.crop_to_bounding_box(image_array, top, left, new_height, new_width)

    # Resize the cropped image
    image_resized = tf.image.resize(image_cropped, target_size)
    return image_resized


def preprocess_data_part1(labels_df, IMAGE_PATH, target_size = IMAGE_SIZE):
    """
    Generate lists of croppe and resized images (as numpy arrays) and labels.

    Params:
    -------
    IMAGE_PATH (str): Path to directory with the images.
    labels_df (pd.DataFrame): Dataframe with labels and paths to images.

    Returns:
    --------
    X (np.ndarray): Array of keras img objects. Images of shape (N, target_height, target_width, 3)
    y (np.ndarray): Labels of shape (N,)
    """
    images = []
    labels = []

    # Create lists of images and labels
    for idx, row in labels_df.iterrows():
        img_path = row['path']
        label = row['label_encoded']

        # Add label to y list
        labels.append(label)

        # Read image
        img = load_img(os.path.join(IMAGE_PATH, img_path))
        img_array = img_to_array(img)

        # call my custom function to crop and resize the image
        img_array = image_crop_and_resize(img_array, target_size=target_size)

        # Append to images list
        images.append(img_array)

    # Stack images and transform into an array
    images = np.stack(images)
    labels = np.array(labels).flatten()

    return images, labels

# %%
X, y = preprocess_data_part1(labels, IMAGES_FOLDER_PATH)

print(f"X (images) shape {X.shape}")
print(f"y shape {y.shape}")
# Out:
# X (images) shape (5337, 180, 120, 3)
# y shape (5337,)

# %%
print(y)
# Out:
# [3 3 3 ... 2 2 2]

# %%
def data_split_and_augment(images, labels, splits):
    """ Split data into train, validation and test sets; apply augmentations

    Params:
    -------
    images  (np.ndarray): Images of shape (N, 224, 224, 3)
    labels (np.ndarray): Labels of shape (N,)
    splits (tuple): 3 values summing to 1 defining split of train, validation and test sets

    Returns:
    --------
    X_train (np.ndarray): Train images of shape (N_train, 224, 224, 3)
    y_train (np.ndarray): Train labels of shape (N_train,)
    X_val (np.ndarray): Val images of shape (N_val, 224, 224, 3)
    y_val (np.ndarray): Val labels of shape (N_val,)
    X_test (np.ndarray): Test images of shape (N_test, 224, 224, 3)
    y_test (np.ndarray): Test labels of shape (N_test,)
    """

    # NOTE: Each time you run this cell, you'll re-shuffle the data. The ordering will be the same due to the random seed generator
    tf.random.set_seed(1234)
    np.random.seed(1234)

    # shuffle data
    idx = np.random.permutation(images.shape[0])
    images, labels = images[idx], labels[idx]

    # create data splits (training, val, and test sets)
    split_points = [int(splits[0] * len(images)), int((splits[0]+splits[1]) * len(images))]
    X_train, X_val, X_test = np.split(images, [split_points[0], split_points[1]])
    y_train, y_val, y_test = np.split(labels, [split_points[0], split_points[1]])

    # image augmentation (random flip) on training data
    X_train_augm = tf.image.random_flip_left_right(X_train)

    # concatenate original X_train and augmented X_train_augm data (will double the count of images)
    X_train = tf.concat([X_train, X_train_augm], axis=0)

    # concatenate y_train (note the label is preserved)
    # y_train = tf.concat([y_train, y_train],axis=0)
    y_train = np.concatenate([y_train, y_train], axis=0)

    # shuffle X_train and y_train, i.e., shuffle two tensors in the same order
    shuffle = tf.random.shuffle(tf.range(tf.shape(X_train)[0], dtype=tf.int32))
    X_train = tf.gather(X_train, shuffle) # transform X back to numpy array instead of tensor
    y_train = tf.gather(y_train, shuffle) # transform y back to numpy array instead of tensor

    # rescale training, val, and test images by dividing each pixel by 255.0
    X_train = X_train / 255.0
    X_val = X_val / 255.0
    X_test = X_test / 255.0

    return X_train, y_train, X_val, y_val, X_test, y_test


# define splits
split = (0.6, 0.2, 0.2)
X_train, y_train, X_val, y_val, X_test, y_test = data_split_and_augment(X, y, split)


print(f"X_train shape {X_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"X_val shape {X_val.shape}")
print(f"y_val shape {y_val.shape}")
print(f"X_test shape {X_test.shape}")
print(f"y_test shape {y_test.shape}")
# Out:
# X_train shape (6404, 180, 120, 3)
# y_train shape (6404,)
# X_val shape (1067, 180, 120, 3)
# y_val shape (1067,)
# X_test shape (1068, 180, 120, 3)
# y_test shape (1068,)

# %%
# delete the X and Y arrays to free up more space in RAM
del X
del y

# %%
print(y_train)
# Out:
# tf.Tensor([1 4 1 ... 1 4 1], shape=(6404,), dtype=int64)

# %% [markdown]
# # Creating the CNN models and Hypertuning

# %%
# Define the basic CNN model
def create_basic_cnn_model(input_shape):
    model = Sequential()

    # Convolutional layer
    model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))

    # Max pooling layer
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Flattening layer
    model.add(Flatten())

    # Dense layer
    model.add(Dense(units=128, activation='relu'))

    # Output layer
    model.add(Dense(units=5, activation='softmax'))

    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=tf.keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

    return model


input_shape = (180, 120, 3)

# Create and summarize the basic CNN model
basic_cnn_model = create_basic_cnn_model(input_shape)
basic_cnn_model.summary()

# Train the basic CNN model
history_basic = basic_cnn_model.fit(X_train, y_train,
                                    epochs=3,
                                    batch_size=32,
                                    validation_data=(X_val, y_val),
                                    callbacks=[tf.keras.callbacks.EarlyStopping(patience=3)])


train_loss, train_accuracy = basic_cnn_model.evaluate(X_train, y_train)
val_loss, val_accuracy = basic_cnn_model.evaluate(X_val, y_val)

print("Training loss:", train_loss)
print("Training accuracy:", train_accuracy)
print("Val loss:", val_loss)
print("Val accuracy:", val_accuracy)
# Out:
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_28 (Conv2D)                   │ (None, 178, 118, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_25 (MaxPooling2D)      │ (None, 89, 59, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_17 (Flatten)                 │ (None, 168032)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_34 (Dense)                     │ (None, 128)                 │      21,508,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_35 (Dense)                     │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 21,509,765 (82.05 MB)
#  Trainable params: 21,509,765 (82.05 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/2
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 184s 908ms/step - accuracy: 0.3018 - loss: 3.0148 - val_accuracy: 0.4724 - val_loss: 1.3226
# Epoch 2/2
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 198s 886ms/step - accuracy: 0.5709 - loss: 1.1171 - val_accuracy: 0.5098 - val_loss: 1.2435
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - accuracy: 0.7477 - loss: 0.7882
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - accuracy: 0.5264 - loss: 1.2408
# Training loss: 0.7863708734512329
# Training accuracy: 0.750312328338623
# Val loss: 1.243544101715088
# Val accuracy: 0.5098406672477722

# %%
def create_complex_cnn_model(input_shape):
    model = Sequential()

    # First convolutional block
    model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))

    # Second convolutional block
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))

    # Third convolutional block
    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))

    # Flattening layer
    model.add(Flatten())

    # Fully connected layer
    model.add(Dense(units=128, activation='relu'))
    model.add(Dropout(0.5))

    # Output layer
    model.add(Dense(units=5, activation='softmax'))

    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), loss=tf.keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

    return model


input_shape = (180, 120, 3)

# Create and summarize the more complex CNN model
complex_cnn_model = create_complex_cnn_model(input_shape)
complex_cnn_model.summary()

# Train the complex CNN model
history_complex = complex_cnn_model.fit(X_train, y_train,
                                        epochs=5,
                                        batch_size=25,
                                        validation_data=(X_val, y_val),
                                        callbacks=[tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)])


train_loss2, train_accuracy2 = complex_cnn_model.evaluate(X_train, y_train)
val_loss2, val_accuracy2 = complex_cnn_model.evaluate(X_val, y_val)

print("Training loss:", train_loss2)
print("Training accuracy:", train_accuracy2)
print("Val loss:", val_loss2)
print("Val accuracy:", val_accuracy2)
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_14 (Conv2D)                   │ (None, 178, 118, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, 178, 118, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 89, 59, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 89, 59, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_15 (Conv2D)                   │ (None, 87, 57, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_10               │ (None, 87, 57, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_15 (MaxPooling2D)      │ (None, 43, 28, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 43, 28, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_16 (Conv2D)                   │ (None, 41, 26, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_11               │ (None, 41, 26, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_16 (MaxPooling2D)      │ (None, 20, 13, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 20, 13, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_8 (Flatten)                  │ (None, 33280)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 128)                 │       4,259,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,354,757 (16.61 MB)
#  Trainable params: 4,354,309 (16.61 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/5
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 442s 2s/step - accuracy: 0.2121 - loss: 28.4082 - val_accuracy: 0.1987 - val_loss: 1.6187
# Epoch 2/5
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 426s 2s/step - accuracy: 0.2168 - loss: 1.8124 - val_accuracy: 0.2062 - val_loss: 1.6027
# Epoch 3/5
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 438s 2s/step - accuracy: 0.2104 - loss: 1.6034 - val_accuracy: 0.2071 - val_loss: 1.6020
# Epoch 4/5
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 446s 2s/step - accuracy: 0.2123 - loss: 1.6139 - val_accuracy: 0.2062 - val_loss: 1.6050
# Epoch 5/5
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 450s 2s/step - accuracy: 0.2151 - loss: 1.6051 - val_accuracy: 0.1996 - val_loss: 1.6065
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 88s 440ms/step - accuracy: 0.2252 - loss: 1.5996
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 15s 431ms/step - accuracy: 0.2240 - loss: 1.6027
# Training loss: 1.6008092164993286
# Training accuracy: 0.22001874446868896
# Val loss: 1.60200035572052
# Val accuracy: 0.2071227729320526

# %% [markdown]
# # Generalization and Confusion Matrix

# %%
#Evaluating the basic model

test_loss_basic, test_acc_basic = basic_cnn_model.evaluate(X_test, y_test)
print(f"Basic CNN Model Test Accuracy: {test_acc_basic:.4f}")

# Evaluate the complex model
test_loss_complex, test_acc_complex = complex_cnn_model.evaluate(X_test, y_test)
print(f"Complex CNN Model Test Accuracy: {test_acc_complex:.4f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 209ms/step - accuracy: 0.4656 - loss: 1.3225
# Basic CNN Model Test Accuracy: 0.4850
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 15s 436ms/step - accuracy: 0.2100 - loss: 1.6024
# Complex CNN Model Test Accuracy: 0.2069

# %%
def plot_accuracy(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy - Training vs. Validation')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.grid(True)
    plt.show()

plot_accuracy(history_basic)

# %%
LABEL_DECODE_DICT = {v: k for k, v in LABEL_ENCODE_DICT.items()}

# Predict the labels for the test set
y_pred = np.argmax(basic_cnn_model.predict(X_test), axis=1)

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=LABEL_DECODE_DICT.values(), yticklabels=LABEL_DECODE_DICT.values())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step
